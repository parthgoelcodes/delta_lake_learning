# %%
from delta.tables import DeltaTable

# %% [markdown]
# #delta api ==adding false ,true for not null and null value

# %%
DeltaTable.createIfNotExists(spark) \
  .tableName("deltalakeparth.default.delta_lake_api2") \
  .addColumn("id", "INT",False) \
  .addColumn("salary", "INT",True) \
  .execute()

# %% [markdown]
# #HOW TO DROP TABLE IN DELTA

# %%
# %sql
DROP TABLE deltalakeparth.default.delta_lake_api2;
